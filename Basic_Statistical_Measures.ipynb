# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthibalraj/Exploratory-Data-Analysis/blob/main/Basic_Statistical_Measures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
my_list = [1, 2, 2, 2, 4, 5, 6, 6, 6, 9, 10, 10, 10, 11, 14, 14, 15, 18, 19, 20]

# %%
# Mean

def get_mean(my_data):
    return sum(my_data)/(len(my_data)*1.0)
get_mean(my_list)
# Out:
# 9.2

# %%
# Median
import numpy as np
np.median(my_list)
# Out:
# 9.5

# %%
# Mode
from scipy.stats import mode
mode(my_list)
# Out:
# ModeResult(mode=2, count=3)

# %%
np.var(my_list)
# Out:
# 33.66

# %%
np.std(my_list)
# Out:
# 5.801723881744114

# %%
np.percentile(my_list,25)
np.percentile(my_list,50)
np.percentile(my_list,75)
# Out:
# 14.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = np.random.normal(50, 5, 3000)

# %%
print("Max is {}".format(max(x)))
print("Min is {}".format(min(x)))
print("Max - Min is {}".format(max(x) - min(x)))
# Out:
# Max is 66.59109952234921
# Min is 27.464037495471786
# Max - Min is 39.127062026877425

# %%
sns.distplot(x, kde=False, bins=5,
             hist_kws=dict(edgecolor="k", linewidth=2))
plt.xlabel('Intervals')
plt.ylabel('Frequency')
plt.show()
# Out:
# <ipython-input-14-69b15cda397f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, kde=False, bins=5,

# %%
sns.distplot(x, kde=False, bins=30,
             norm_hist=True,
             hist_kws=dict(edgecolor="k", linewidth=2))
plt.xlabel('Intervals')
plt.ylabel('Relative Frequency')
plt.show()
# Out:
# <ipython-input-15-62c624cbf331>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, kde=False, bins=30,

# %%
sns.distplot(x, kde=True, bins=30,
             norm_hist=True,
             hist_kws=dict(edgecolor="r", linewidth=2))
plt.xticks(range(28, 70, 4))
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-16-5565ec83d373>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, kde=True, bins=30,

# %%
plt.axvline(x.mean(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(np.median(x), color='r', linestyle='dashed', linewidth=4)
sns.distplot(x, kde=True, bins=30, hist=False)
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-17-a9c4a2a1a305>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, kde=True, bins=30, hist=False)

# %%
import pandas as pd
# Convert the list to dataframe and add column name
df = pd.DataFrame(my_list, columns=['Sample data'])

# Plot using seaborm
sns.boxplot(data=df)

# Add ylabel
plt.ylabel('Data points')
# Out:
# Text(0, 0.5, 'Data points')
